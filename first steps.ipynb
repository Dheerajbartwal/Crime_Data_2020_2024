# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
df
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1        200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2        200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3        200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4        200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630
# ...            ...                     ...                     ...       ...
# 1003443  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 1003444  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 1003445  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 1003446  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 1003447  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003448 entries, 0 to 1003447
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1003448 non-null  int64
#  1   Date Rptd       1003448 non-null  object
#  2   DATE OCC        1003448 non-null  object
#  3   TIME OCC        1003448 non-null  int64
#  4   AREA            1003448 non-null  int64
#  5   AREA NAME       1003448 non-null  object
#  6   Rpt Dist No     1003448 non-null  int64
#  7   Part 1-2        1003448 non-null  int64
#  8   Crm Cd          1003448 non-null  int64
#  9   Crm Cd Desc     1003448 non-null  object
#  10  Mocodes         851881 non-null   object
#  11  Vict Age        1003448 non-null  int64
#  12  Vict Sex        858856 non-null   object
#  13  Vict Descent    858844 non-null   object
#  14  Premis Cd       1003432 non-null  float64
#  15  Premis Desc     1002860 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151567
# Vict Age                0
# Vict Sex           144592
# Vict Descent       144604
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     676308
# Weapon Desc        676308
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           934330
# Crm Cd 3          1001133
# Crm Cd 4          1003384
# LOCATION                0
# Cross Street       849335
# LAT                     0
# LON                     0
# dtype: int64

# %%
df = df.drop(columns=['DR_NO','Rpt Dist No','Part 1-2','Vict Descent','Premis Cd','Weapon Used Cd','Weapon Desc','Crm Cd 2','Crm Cd 3','Crm Cd 4','Cross Street','LAT','LON'])

# %%
df
# Out:
#                       Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0        03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1        02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2        11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3        05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4        09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
# ...                         ...                     ...       ...   ...
# 1003443  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400     7
# 1003444  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100     1
# 1003445  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330     4
# 1003446  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500     3
# 1003447  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300     9
#
#           AREA NAME  Crm Cd  \
# 0          Wilshire     510
# 1           Central     330
# ...

# %%
df['Vict Sex'] = df['Vict Sex'].fillna("Unknown")

# %%
df['Premis Desc'] = df['Premis Desc'].fillna('Unknown')

# %%
df['Crm Cd 1'] = df['Crm Cd 1'].fillna(df['Crm Cd 1'].mean())

# %%
df.head()
# Out:
#                 Date Rptd                DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7    Wilshire
# 1  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1     Central
# 2  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3   Southwest
# 3  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9    Van Nuys
# 4  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4  Hollenbeck
#
#    Crm Cd                               Crm Cd Desc         Mocodes  Vict Age  \
# 0     510                          VEHICLE - STOLEN             NaN         0
# 1     330                     BURGLARY FROM VEHICLE  1822 1402 0344        47
# 2     480                             BIKE - STOLEN       0344 1251        19
# 3     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)       0325 1501        19
# 4     510                          VEHICLE - STOLEN             NaN         0
#
# ...

# %%
df.isnull().sum()
# Out:
# Date Rptd           0
# DATE OCC            0
# TIME OCC            0
# AREA                0
# AREA NAME           0
# Crm Cd              0
# Crm Cd Desc         0
# Mocodes        151567
# Vict Age            0
# Vict Sex            0
# Premis Desc         0
# Status              1
# Status Desc         0
# Crm Cd 1            0
# LOCATION            0
# dtype: int64

# %%
df = df.drop(columns=['Mocodes'])

# %%
df.isnull().sum()
# Out:
# Date Rptd      0
# DATE OCC       0
# TIME OCC       0
# AREA           0
# AREA NAME      0
# Crm Cd         0
# Crm Cd Desc    0
# Vict Age       0
# Vict Sex       0
# Premis Desc    0
# Status         1
# Status Desc    0
# Crm Cd 1       0
# LOCATION       0
# dtype: int64

# %%
df.to_csv("cleaned_file.csv", index=False)
