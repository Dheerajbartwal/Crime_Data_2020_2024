# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Crime_Analysis_date')
df
# Out:
#           AREA NAME  Crm Cd  \
# 0          Wilshire     510
# 1           Central     330
# 2         Southwest     480
# 3          Van Nuys     343
# 4        Hollenbeck     510
# ...             ...     ...
# 1003443    Wilshire     510
# 1003444     Central     745
# 1003445  Hollenbeck     341
# 1003446   Southwest     230
# 1003447    Van Nuys     510
#
#                                                Crm Cd Desc   Vict Age  \
# 0                                         VEHICLE - STOLEN  39.498913
# 1                                    BURGLARY FROM VEHICLE  47.000000
# 2                                            BIKE - STOLEN  19.000000
# 3                 SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  19.000000
# 4                                         VEHICLE - STOLEN  39.498913
# ...                                                    ...        ...
# 1003443                                   VEHICLE - STOLEN  39.498913
# ...

# %%
vict_sex = df['Vict Sex'].value_counts()
vict_sex
# Out:
# M          403194
# F          358012
# Unknown    144592
# X           97535
# H             114
# -               1
# Name: Vict Sex, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot Vict Age counts
vict_sex.plot(kind='bar', figsize=(10, 6),color='red')
plt.title('Distribution of Vict Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
status_desc = df['Status Desc'].value_counts()
status_desc
# Out:
# Invest Cont     803405
# Adult Other     108558
# Adult Arrest     86387
# Juv Arrest        3241
# Juv Other         1850
# UNK                  7
# Name: Status Desc, dtype: int64

# %%
status_desc.plot(kind = 'bar', figsize=(10,6),color='green')
plt.title('Status Description')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
area_name = df['AREA NAME'].value_counts()
area_name
# Out:
# Central        69548
# 77th Street    61703
# Pacific        59347
# Southwest      57357
# Hollywood      52350
# N Hollywood    51019
# Olympic        49997
# Southeast      49894
# Newton         49138
# Wilshire       48148
# Rampart        46772
# West LA        45671
# Northeast      42857
# Van Nuys       42819
# West Valley    42088
# Devonshire     41689
# Harbor         41311
# Topanga        41302
# Mission        40306
# Hollenbeck     37034
# Foothill       33098
# Name: AREA NAME, dtype: int64

# %%
area_name.plot(kind='bar',figsize=(10,3),color='red')
plt.title('Area name')
plt.xlabel('Area')
plt.ylabel('Counts')
plt.show()

# %%
year_counts = df['Year'].value_counts()
year_counts
# Out:
# 2022    235064
# 2023    234651
# 2021    208284
# 2020    192708
# 2024    132741
# Name: Year, dtype: int64

# %%
year_counts.plot(kind='bar',figsize=(10,5),color='orange')
plt.title('Year')
plt.xlabel('year')
plt.ylabel('counts')
plt.show()

# %%
age_month = df['Month-Year'].value_counts()
age_month.head(15)
# Out:
# May 2022         20597
# August 2022      20438
# June 2022        20263
# August 2023      20248
# October 2023     20244
# January 2023     20122
# October 2022     20112
# December 2022    20090
# July 2023        20039
# January 2024     19899
# March 2022       19801
# April 2022       19768
# July 2022        19754
# December 2023    19658
# November 2023    19442
# Name: Month-Year, dtype: int64

# %%
import seaborn as sns

# Load the dataset
data = pd.read_csv('cleaned_file.csv')

# Set up plot style
plt.style.use('seaborn-darkgrid')

# 1. Crime Frequency by Area (Bar Plot)
plt.figure(figsize=(12, 6))
area_counts = data['AREA NAME'].value_counts()
sns.barplot(x=area_counts.index, y=area_counts.values, palette='viridis')
plt.title('Crime Frequency by Area', fontsize=16)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Area Name', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Top 15 Most Common Crime Types (Bar Plot)

plt.figure(figsize=(12, 6))
crime_counts = data['Crm Cd Desc'].value_counts()[:15]
sns.barplot(y=crime_counts.index, x=crime_counts.values, palette='coolwarm')
plt.title('Top 15 Most Common Crime Types', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Crime Type', fontsize=12)
plt.show()

# %%
# 3. Victim Age Distribution (Histogram)

plt.figure(figsize=(10, 6))
sns.histplot(data['Vict Age'], bins=30, kde=True, color='orange')
plt.title('Victim Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# 4. Crime Occurrences by Time of Day (Line Plot)
plt.figure(figsize=(12, 6))
time_counts = data['TIME OCC'].value_counts().sort_index()
sns.lineplot(x=time_counts.index, y=time_counts.values, color='green')
plt.title('Crime Occurrences by Time of Day', fontsize=16)
plt.xlabel('Time (24-Hour Clock)', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.show()

# %%
# 5. Victim Gender Distribution (Pie Chart)
plt.figure(figsize=(8, 8))
gender_counts = data['Vict Sex'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'pink', 'lightgray'])
plt.title('Victim Gender Distribution', fontsize=16)
plt.show()

# %%
# 6. Case Status Distribution (Pie Chart)
plt.figure(figsize=(8, 8))
status_counts = data['Status Desc'].value_counts()
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set2', len(status_counts)))
plt.title('Case Status Distribution', fontsize=16)
plt.show()

# %%
# 7. Crime Frequency by Premises Description (Bar Plot)
plt.figure(figsize=(12, 6))
premis_counts = data['Premis Desc'].value_counts()[:15]
sns.barplot(y=premis_counts.index, x=premis_counts.values, palette='magma')
plt.title('Top 15 Premise Descriptions for Crimes', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Premise Description', fontsize=12)
plt.show()

# %%
data
# Out:
#                       Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0        03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1        02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2        11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3        05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4        09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
# ...                         ...                     ...       ...   ...
# 1003443  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400     7
# 1003444  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100     1
# 1003445  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330     4
# 1003446  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500     3
# 1003447  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300     9
#
#           AREA NAME  Crm Cd  \
# 0          Wilshire     510
# 1           Central     330
# ...
